# %%
import rasterio as rio 
import matplotlib.pyplot as plt

# scribble as example
# TODO: high as example
with rio.open("data/p509/scribble/train/ROI_5517/20181227T082339_20181227T083350_T35NNB.tif") as src:
    cloud_mask = src.read(1)
    # band 15 is manual GT
    # classes are 
    # 0 clear
    # 1 thick cloud
    # 2 thin cloud
    # 3 cloud shadow

    plt.imshow(cloud_mask)# , cmap="tab10")
    plt.colorbar(label="class id")
    plt.title("CloudSEN12 Semantic Mask")
    plt.show()
