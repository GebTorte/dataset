# %%
import polars as pl

# %%
df = pl.read_csv('data/cloudsen12_initial.csv')

# %%
df_filtered = df.filter(pl.col("cloud_per") == 0)

# %%
df_filtered.head(10).write_csv('data/cloudsen12_initial_cloudfree_dev.csv')
