# %%
import polars as pl

# %%
df = pl.read_csv('data/cloudsen12_initial.csv')

# %%
qualities = ["high"] # one or more of scribble/high/nolabel

# %%
#df_filtered = df.filter(pl.col("cloud_per") == 0).filter(pl.col("label_type").is_in(qualities))
#df_filtered

# %%
df_filtered = df.filter(pl.col("label_type").is_in(qualities))
df_filtered
# Out:
# shape: (10_000, 8)
# ┌─────────┬──────────┬─────────────┬───────────┬────────────┬────────────┬────────────┬────────────┐
# │ user    ┆ ROI      ┆ sen2        ┆ cloud_per ┆ cloud_cove ┆ label_type ┆ difficulty ┆ proj_centr │
# │ ---     ┆ ---      ┆ ---         ┆ ---       ┆ rage       ┆ ---        ┆ ---        ┆ oid        │
# │ str     ┆ str      ┆ str         ┆ f64       ┆ ---        ┆ str        ┆ str        ┆ ---        │
# │         ┆          ┆             ┆           ┆ str        ┆            ┆            ┆ str        │
# ╞═════════╪══════════╪═════════════╪═══════════╪════════════╪════════════╪════════════╪════════════╡
# │ JHOMIRA ┆ ROI_0001 ┆ 20200308T14 ┆ 0.0       ┆ cloud-free ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 1731_202003 ┆           ┆            ┆            ┆            ┆ (-69.78524 │
# │         ┆          ┆ 08T14355…   ┆           ┆            ┆            ┆            ┆ -49.00794) │
# │ JHOMIRA ┆ ROI_0001 ┆ 20190304T14 ┆ 12.5      ┆ almost-cle ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 2031_201903 ┆           ┆ ar         ┆            ┆            ┆ (-69.78524 │
# │         ┆          ┆ 04T14265…   ┆           ┆            ┆            ┆            ┆ -49.00794) │
# │ JHOMIRA ┆ ROI_0001 ┆ 20190212T14 ┆ 35.0      ┆ low-cloudy ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 2031_201902 ┆           ┆            ┆            ┆            ┆ (-69.78524 │
# │         ┆          ┆ 12T14321…   ┆           ┆            ┆            ┆            ┆ -49.00794) │
# │ JHOMIRA ┆ ROI_0001 ┆ 20190525T14 ┆ 55.0      ┆ mid-cloudy ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 1059_201905 ┆           ┆            ┆            ┆            ┆ (-69.78524 │
# │         ┆          ┆ 25T14205…   ┆           ┆            ┆            ┆            ┆ -49.00794) │
# │ JHOMIRA ┆ ROI_0001 ┆ 20190316T14 ┆ 82.5      ┆ cloudy     ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 1049_201903 ┆           ┆            ┆            ┆            ┆ (-69.78524 │
# │         ┆          ┆ 16T14243…   ┆           ┆            ┆            ┆            ┆ -49.00794) │
# │ …       ┆ …        ┆ …           ┆ …         ┆ …          ┆ …          ┆ …          ┆ …          │
# │ NICOLE  ┆ ROI_9992 ┆ 20200322T06 ┆ 0.0       ┆ cloud-free ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 0629_202003 ┆           ┆            ┆            ┆            ┆ (69.38005  │
# │         ┆          ┆ 22T06111…   ┆           ┆            ┆            ┆            ┆ 33.98028)  │
# │ NICOLE  ┆ ROI_9992 ┆ 20190422T06 ┆ 12.5      ┆ almost-cle ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 0641_201904 ┆           ┆ ar         ┆            ┆            ┆ (69.38005  │
# │         ┆          ┆ 22T06115…   ┆           ┆            ┆            ┆            ┆ 33.98028)  │
# │ NICOLE  ┆ ROI_9992 ┆ 20200630T06 ┆ 35.0      ┆ low-cloudy ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 0639_202006 ┆           ┆            ┆            ┆            ┆ (69.38005  │
# │         ┆          ┆ 30T06120…   ┆           ┆            ┆            ┆            ┆ 33.98028)  │
# │ NICOLE  ┆ ROI_9992 ┆ 20200228T05 ┆ 55.0      ┆ mid-cloudy ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 5759_202002 ┆           ┆            ┆            ┆            ┆ (69.38005  │
# │         ┆          ┆ 28T06052…   ┆           ┆            ┆            ┆            ┆ 33.98028)  │
# │ NICOLE  ┆ ROI_9992 ┆ 20191006T05 ┆ 82.5      ┆ cloudy     ┆ high       ┆ NA         ┆ POINT      │
# │         ┆          ┆ 5711_201910 ┆           ┆            ┆            ┆            ┆ (69.38005  │
# │         ┆          ┆ 06T06052…   ┆           ┆            ┆            ┆            ┆ 33.98028)  │
# └─────────┴──────────┴─────────────┴───────────┴────────────┴────────────┴────────────┴────────────┘

# %%
df_filtered.write_csv('data/cloudsen12_initial_high_validation.csv')
